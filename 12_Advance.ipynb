# %% [markdown]
# # ADVANCE PYTHON

# %% [markdown]
# **Walrus operator (:=)**
# - Introduced in Python 3.8
# - Allows you to assign values to variables as part of an expression.
# - This operator, named for its resemblance to the eyes and tusks of a walrus
# - Is officially called the "assignment expression.

# %%
if (n := len([1, 2, 3, 4, 5])) > 3: #n is assigned the value of len([1, 2, 3, 4, 5]) & then used in the comparison within the if statement. 
    print(f"List is too long ({n} elements, expected <= 3)")
# Out:
# List is too long (5 elements, expected <= 3)

# %% [markdown]
# **TYPES Hints**
# - Type hints are added using the colon (:) syntax for variables & the -> syntax for
# - function return types.
# - These annotations help in making the code self-documenting and allow developers to
# - understand the data structures used at a glance

# %%
age: int = 25 # Variable type hint 

def greeting(name: str) -> str: # Function type hints 
    return f"Hello, {name}!" 

print(greeting("Alice"))  # Output: Hello, Alice!
# Out:
# Hello, Alice!

# %% [markdown]
# **Advanced type hints**
# - such as List, Tuple, Dict, & Union.

# %%
from typing import List, Tuple, Dict, Union #You can import List, Tuple and Dict types from the typing module 

numbers: List[int] = [1, 2, 3, 4, 5] # List of integers
person: Tuple[str, int] = ("Alice", 30)  # Tuple of a string and an integer 
scores: Dict[str, int] = {"Alice": 90, "Bob": 85} # Dictionary with string keys and integer values 

identifier: Union[int, str] = "ID123" # Union type for variables that can hold multiple types 
# identifier = 12345  # Also valid
print(numbers)
print(person)
print(scores)
print(identifier)
# Out:
# [1, 2, 3, 4, 5]
# ('Alice', 30)
# {'Alice': 90, 'Bob': 85}
# ID123

# %% [markdown]
# **MATCH CASE**
# - Python 3.10 introduced the match statement
# - similar to the switch statement found in other programming languages
# - The basic syntax of the match statement involves matching a variable against several
# - cases using the case keyword.

# %%
def http_status(status): 
    match status: 
        case 200: 
            return "OK" 
        case 404: 
            return "Not Found" 
        case 500: 
            return "Internal Server Error" 
        case _: 
            return "Unknown status" 

print(http_status(200))  # Output: OK 
print(http_status(404))  # Output: Not Found 
print(http_status(500))  # Output: Internal Server Error 
print(http_status(403))  # Output: Unknown status
# Out:
# OK
# Not Found
# Internal Server Error
# Unknown status

# %% [markdown]
# **DICTIONARY MERGE & UPDATE OPERATORS**

# %%
dict1 = {'a': 1, 'b': 2} 
dict2 = {'b': 3, 'c': 4} 
merged = dict1 | dict2  # New operators | and |= allow for merging and updating dictionaries.
print(merged)           # Output: {'a': 1, 'b': 3, 'c': 4}
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %% [markdown]
# **with Statement**
# - You can now use multiple context managers in a single with statement more cleanly using the parenthesised context manager

# %%
with ( 
    open('table.txt') as f1,  
    open('practice.txt') as f2 
):
    data1 = f1.read()
    data2 = f2.read()
    print("file 1:",data1)
    print("File 2:",data2)
    print("files opened succesfully!")
# Out:
# file 1: Table of 3:[3, 6, 9, 12, 15, 18, 21, 24, 27, 30] Table of 4:[4, 8, 12, 16, 20, 24, 28, 32, 36, 40]
# File 2: 1,2,3,4,20,100.
# Hi everyone
#  we are learning File I/O
#  using Python.
#  I like programming in Python.
#
#  I also like programming in C++.
#  I also like programming in C++.
# files opened succesfully!

# %% [markdown]
# **EXCEPTION HANDLING**
# - There are many built-in exceptions which are raised in python when something goes  wrong.
# - Exception in python can be handled using a try statement. The code that handles the exception is written in the except clause.
# - When the exception is handled, the code flow continues without program interruption.

# %%
try:
    a = int(input("Hey, Enter a no:"))
    print(a)
except ValueError as v:
    print("heyy")
    print(v)

except Exception as e:  # Code which might throw exception 
    print(e)

print("Thanks")
 
# We can also specify the exception to catch like below:
# try: 
#     # Code 
# except ZeroDivisionError: #for division by zero
#     # Code 
# except TypeError: 
#     # Code 
# except: 
#     # Code     # All other exceptions are handled here.
# Out:
# 4
# Thanks

# %% [markdown]
# **RAISING EXCEPTIONS**
# - We can raise custom exceptions using the ‘raise’ keyword in python

# %%
a = int(input("Enter a:"))
b = int(input("Enter b:"))

if(b==0):
    raise ZeroDivisionError("Hey our program don't support division by zero")
else:
    print(f"The division a/b is {a/b}")
# Out:
# The division a/b is 1.0

# %% [markdown]
# **TRY WITH ELSE CLAUSE**
# - Sometimes we want to run a piece of code when try was successful.

# %%
try: 
    a = int(input("enter a number"))
    print(a)
except Exception as e:
    print(e) 
else: 
    print("I am inside else")        # This is executed only if the try was successful
# Out:
# 4
# I am inside else

# %% [markdown]
# **TRY WITH FINALLY**
# - Python offers a ‘finally’ clause which ensures execution of piece of code inspective of the exception.

# %%
def main():
    try:
        a = int(input("hey, Enter a Number"))
        print(a)
        return

    except Exception as e:
        print(e)
        return

    finally:
        print("Hey I am inside of finally") #Executed regardless of error!

main()
# Out:
# 4
# Hey I am inside of finally

# %% [markdown]
# **THE GLOBAL KEYWORD**
# - 'global' keyword is used to modify the global variable outside of the current scope.
#
# ***Global variable***
# - a variable declared Outside of any function or class block, making it accessible from anywhere within the same code module
# - global variables are not restricted to one block of code they can be changed throughtout the program
#
# ***Local variable***
# - local variables are restricted to only one block of code & cannot be changed throughout the program.

# %%
a = 89 #local variable
print("local variable:",a)

def fun():
    global a #global keyword:now that local variable becomes global
    a = 3
    print(a)

fun()
print("Global variable:",a)
# Out:
# local variable: 89
# 3
# Global variable: 3

# %% [markdown]
# **ENUMERATE FUNCTION**
# - The ‘enumerate’ function adds counter to an iterable and returns it

# %%
fruits = ["Apple"," Mango", "Banana"]

index = 0
for item in fruits: #we can also write for fruit in fruits
    print(f"USING FOR LOOP: The item number at index {index} is {item}")
    index += 1

for index, item in enumerate(fruits): #simplified using enumerate function
    print(f"USING ENUMERATE FUNC:The item number at index {index} is {item}")
# Out:
# USING FOR LOOP: The item number at index 0 is Apple
# USING FOR LOOP: The item number at index 1 is  Mango
# USING FOR LOOP: The item number at index 2 is Banana
# USING ENUMERATE FUNC:The item number at index 0 is Apple
# USING ENUMERATE FUNC:The item number at index 1 is  Mango
# USING ENUMERATE FUNC:The item number at index 2 is Banana

# %% [markdown]
# **LIST COMPREHENSIONS**
# - List Comprehension is an elegant way to create lists based on existing lists

# %%
mylist = [1, 2, 3, 5, 7, 11]

sqlist = []
for item in mylist:
    sqlist.append(item*item)

print(f"USING FOR LOOP{sqlist}")

squaredlist = [i*i for i in mylist] 
print(f"USING LIST COMPRE{squaredlist}")
# Out:
# USING FOR LOOP[1, 4, 9, 25, 49, 121]
# USING LIST COMPRE[1, 4, 9, 25, 49, 121]

# %% [markdown]
# **LAMBDA FUNCTIONS**
#  - It is used when an anonymous function is required for a short period of time.
# - It can take numerous arguments.
# - But can only have one expression. The expression is evaluated and returned.
# - Function created using an expression using ‘lambda’ keyword.
# - SYNTAX: lambda arguments:expressions # can be used as a normal function

# %% [markdown]
# - In Jupyter notebook we ca run only a single code without using print in a single block

# %%
sq = lambda x: x*x 
print(sq(6))  # returns 36

sum = lambda a,b,c: a+b+c 
sum(1,2,3) # returns 6
# Out:
# 36
# 6

# %% [markdown]
# **JOIN METHOD (STRINGS)**
# - Creates a string from iterable objects.

# %%
l = ["apple", "mango", "banana"] 
result = "::".join(l) 
print(result) #apple::mango::banana
# Out:
# apple::mango::banana

# %% [markdown]
# **FORMAT METHOD (STRINGS)**
# - Formats the values inside the string into a desired output
# - template.format(p1,p2...)

# %%
"{0} is a good {1}".format("harry", "boy")   #1.harry is a good boy
# Out:
# 'harry is a good boy'

# %%
"{1} is a good {0}".format("harry", "boy")  #2.boy is a good harry
# Out:
# 'boy is a good harry'

# %% [markdown]
# **Map**
# - Map applies a function to all the items in an input_list.

# %%
#map
i = [1, 2, 3, 4, 5]
sq = lambda x: x*x
sqlist = map(sq, i)
print(list(sqlist))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# **Filter**
# - Filter creates a list of items for which the function returns true.

# %%
def even(n):
    if (n%2 == 0):
        return True
    return False #no need to use else because if the statement is true it will return value otherwise it will return false
onlyEven = filter(even,i)
print(list(onlyEven))
# Out:
# [2, 4]

# %% [markdown]
# **Reduce Function**
# - Reduce applies a rolling computation to sequential pair of elements.

# %%
from functools import reduce
def sum(a,b):
    return a + b
print("Sum:",reduce(sum,i))

def mul(a,b):
    return a * b
print("Multiple:",reduce(mul,i))
# Out:
# Sum: 15
# Multiple: 120
