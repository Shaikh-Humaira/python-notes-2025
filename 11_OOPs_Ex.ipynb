# %%
# Q1. Define a circle class to create a circle with radius r using the constructor.
# Define an Area()method of the class which calculates the area of the circle.
# Define a Perimeter () method of the class which allows you  to calculate the perimeter of the circle.

class Circle:
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        return 22/7 * self.radius ** 2
    def perimeter(self):
        return 2 * 22/7 * self.radius
c1 = Circle(21)
print("Area of the circle:", c1.area())
print("Perimeter of the circle:", c1.perimeter())
# Out:
# Area of the circle: 1386.0
# Perimeter of the circle: 132.0

# %%
#Q2. Define a Engineer class with attributes  name & age
#create an Employee classthat inherits properties from engineer & has additional attributes: role, department & salary. Both class also has a showdetails() method 
class Engineer:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def showdetail(self):
            print("Name:",self.name,"Age:",self.age)
        
class Employee(Engineer):
    def __init__(self,role, dept,salary):
        self.role = role
        self.dept = dept
        self.salary = salary
        super().__init__("Humaira","19")

    def showdetails(self):
            print("role:",self.role,"dept:",self.dept,"salary:",self.salary)


E1 = Employee("Data Scientist","Data","2,00,000")
E1.showdetail()
E1.showdetails()
# Out:
# Name: Humaira Age: 19
# role: Data Scientist dept: Data salary: 2,00,000

# %%
#Create a class called Order Which stores items & its price.
#use Dunder function __g__() to convey that:
#order1 > order2 if price of order1 > price of order2

class Order:
    def __init__(self,items,price):
        self.items = items
        self.price = price

    def __gt__(self, odr2):
        return self.price > odr2.price

odr1 = Order("Icecream",20)
odr2 = Order("burger", 19)

print(odr1 > odr2) #true
# Out:
# True

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

circle = Circle(5)
print(circle.area())
# Out:
# 78.5
